# %% [markdown]
# # Pandas Built-in Data Visualization
#
# Hi Guys,<br>
# Welcome to [pandas for Data Visualization](https://pandas.pydata.org/pandas-docs/stable/visualization.html) now. In the Data Analysis section, we have explored the power of pandas for data analysis. Let's talk about pandas built-in data visualization capabilities. We can create decent looking plots using pandas. This is actually built on matplotlib and embedded into pandas for quick use. <br>
#
# Let's take a look!
# ### Histograms
# ### Area plot
# ### Bar plots
# ### Line plots
# ### Scatter plots
# ### BoxPlots
# ### Pie Plot

# %%
# let's do some imports first
import numpy as np
import pandas as pd

# %% [markdown]
# Let's create some random datasets now! <br>
# df1 with date as index and df2 with sequential index.
#
# *Although, we can use seaborn built-in datasets as well. To make this lecture as a separate and independent, I am creating new data frames here to use.*

# %% [markdown]
# ### Generating `df1`

# %%
# We can use date_range function from pandas
# periods = 500, no of periods (days) to generate
dates = pd.date_range('1/1/2022', periods=500)
dates
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2023-05-06', '2023-05-07', '2023-05-08', '2023-05-09',
#                '2023-05-10', '2023-05-11', '2023-05-12', '2023-05-13',
#                '2023-05-14', '2023-05-15'],
#               dtype='datetime64[ns]', length=500, freq='D')

# %%
# Let's use numpy's randn for "standard normal" distribution
data1 = np.random.randn(500,3) #(500,3) to tell the shape we want
data1
# Out:
# array([[ 2.64339028e-01, -6.76687080e-01, -2.09922247e+00],
#        [ 9.79176070e-01,  8.32977686e-01, -4.30470558e-01],
#        [ 6.75411374e-01, -1.26009893e+00,  8.87873998e-02],
#        ...,
#        [-1.78038919e+00, -2.81301975e-01,  1.63237842e-01],
#        [ 6.27450501e-01,  8.51779717e-01,  1.47361689e-03],
#        [ 1.04741697e-01, -1.00619344e+00,  1.21274771e+00]])

# %%
# randn(1000,4) 1000 by 4 2D array
df1 = pd.DataFrame(data = data1, index=dates, columns=['A', 'B', 'C'])

# %%
df1
# Out:
#                    A         B         C
# 2022-01-01  0.264339 -0.676687 -2.099222
# 2022-01-02  0.979176  0.832978 -0.430471
# 2022-01-03  0.675411 -1.260099  0.088787
# 2022-01-04  0.991862  0.025384 -0.668000
# 2022-01-05  0.543609 -0.012461 -0.337794
# ...              ...       ...       ...
# 2023-05-11  0.524144  0.489644  1.619630
# 2023-05-12  2.729420  1.816363 -0.429863
# 2023-05-13 -1.780389 -0.281302  0.163238
# 2023-05-14  0.627451  0.851780  0.001474
# 2023-05-15  0.104742 -1.006193  1.212748
#
# [500 rows x 3 columns]

# %% [markdown]
# Let's add D as a column to df1

# %%
# Let's generate a series using rand()
df1['D'] = np.random.rand(500)

# %%
df1
# Out:
#                    A         B         C         D
# 2022-01-01  0.264339 -0.676687 -2.099222  0.349654
# 2022-01-02  0.979176  0.832978 -0.430471  0.191758
# 2022-01-03  0.675411 -1.260099  0.088787  0.171498
# 2022-01-04  0.991862  0.025384 -0.668000  0.102852
# 2022-01-05  0.543609 -0.012461 -0.337794  0.078712
# ...              ...       ...       ...       ...
# 2023-05-11  0.524144  0.489644  1.619630  0.418202
# 2023-05-12  2.729420  1.816363 -0.429863  0.178136
# 2023-05-13 -1.780389 -0.281302  0.163238  0.687459
# 2023-05-14  0.627451  0.851780  0.001474  0.094138
# 2023-05-15  0.104742 -1.006193  1.212748  0.059543
#
# [500 rows x 4 columns]

# %% [markdown]
# ### Generating `df2`

# %%
# rand(20,3) 20 by 3 2D array
data2 = np.random.rand(20,3)
col = ['X', 'Y', 'Z']
df2 = pd.DataFrame(data = data2, columns=col)

# %%
df2
# Out:
#            X         Y         Z
# 0   0.663015  0.148580  0.980193
# 1   0.713478  0.619036  0.586946
# 2   0.079258  0.195923  0.962479
# 3   0.220901  0.575650  0.929624
# 4   0.307289  0.910089  0.809238
# 5   0.088602  0.858756  0.575100
# 6   0.597550  0.003391  0.158426
# 7   0.524294  0.622006  0.330956
# 8   0.884356  0.532413  0.989198
# 9   0.113992  0.706258  0.009953
# 10  0.098305  0.634802  0.311435
# 11  0.687696  0.262317  0.994510
# 12  0.155237  0.023567  0.201243
# 13  0.986107  0.426543  0.299360
# 14  0.556604  0.459840  0.086019
# 15  0.162505  0.162553  0.766905
# 16  0.350114  0.694393  0.697621
# 17  0.365398  0.809179  0.602207
# 18  0.708962  0.786144  0.717505
# 19  0.111254  0.103850  0.053659

# %% [markdown]
# Let's start with simple histogram plot, we can get the hist plot in two ways!
# * `DataFrame.hist()`
# * `DataFrame.plot(kind = 'hist')`
#
# Let's try both one-by-one first, later on, we will talk about style sheet and discuss the range of plotting options in details!

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(bins=30, edgecolor='black',figsize=(12,5))    # bins = 30 means 30 bars
# Out:
# <Axes: >

# %%
# we can also plot using kind
df1['A'].plot(kind='hist',bins=30, edgecolor='black')   # Using default figure size
# Out:
# <Axes: ylabel='Frequency'>

# %%
# For whole dataset
df1.plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Style Sheets
#
# Matplotlib has [style sheets](http://matplotlib.org/gallery.html#style_sheets). We can use this to make our plots look a little nicer. These style sheets include `plot_bmh`,`plot_fivethirtyeight`,`plot_ggplot` and more. They basically create a set of style rules that our plots follow. Its good to use them because they make all our plots to have the same look and feel more professional. <br>
# Let's call the style first!

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
# Lets use another style "bmh"
plt.style.use('bmh')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
# we can use dark_background
plt.style.use('dark_background')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
# another example
plt.style.use('fivethirtyeight')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
df2['X'].plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Plot Types
#
# There are several plot types built-in to pandas, most of them are statistical plots by nature:
#
# * `df.plot.area`
# * `df.plot.bar`
# * `df.plot.barh`
# * `df.plot.hist`
# * `df.plot.line`
# * `df.plot.scatter`
# * `df.plot.box`
# * `df.plot.pie`
#
# We can also just call `df.plot(kind='hist')` or replace that kind argument with any of the key terms shown in the list above (e.g. `'box','barh'`, etc..)<br>
# **Let's go through these plots one-by-one using our data frames `df1` and `df2`!**

# %% [markdown]
# ### Area plot

# %%
df2
# Out:
#            X         Y         Z
# 0   0.663015  0.148580  0.980193
# 1   0.713478  0.619036  0.586946
# 2   0.079258  0.195923  0.962479
# 3   0.220901  0.575650  0.929624
# 4   0.307289  0.910089  0.809238
# 5   0.088602  0.858756  0.575100
# 6   0.597550  0.003391  0.158426
# 7   0.524294  0.622006  0.330956
# 8   0.884356  0.532413  0.989198
# 9   0.113992  0.706258  0.009953
# 10  0.098305  0.634802  0.311435
# 11  0.687696  0.262317  0.994510
# 12  0.155237  0.023567  0.201243
# 13  0.986107  0.426543  0.299360
# 14  0.556604  0.459840  0.086019
# 15  0.162505  0.162553  0.766905
# 16  0.350114  0.694393  0.697621
# 17  0.365398  0.809179  0.602207
# 18  0.708962  0.786144  0.717505
# 19  0.111254  0.103850  0.053659

# %%
df2['X'].plot()
# Out:
# <Axes: >

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2['X'].plot(kind='area')
# Out:
# <Axes: >

# %%
df2.plot.area()
# Out:
# <Axes: >

# %% [markdown]
# ### Bar plots

# %%
df2
# Out:
#            X         Y         Z
# 0   0.663015  0.148580  0.980193
# 1   0.713478  0.619036  0.586946
# 2   0.079258  0.195923  0.962479
# 3   0.220901  0.575650  0.929624
# 4   0.307289  0.910089  0.809238
# 5   0.088602  0.858756  0.575100
# 6   0.597550  0.003391  0.158426
# 7   0.524294  0.622006  0.330956
# 8   0.884356  0.532413  0.989198
# 9   0.113992  0.706258  0.009953
# 10  0.098305  0.634802  0.311435
# 11  0.687696  0.262317  0.994510
# 12  0.155237  0.023567  0.201243
# 13  0.986107  0.426543  0.299360
# 14  0.556604  0.459840  0.086019
# 15  0.162505  0.162553  0.766905
# 16  0.350114  0.694393  0.697621
# 17  0.365398  0.809179  0.602207
# 18  0.708962  0.786144  0.717505
# 19  0.111254  0.103850  0.053659

# %%
df2['X'].plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %%
# Horizontal bars
df2.plot.barh(figsize=(10,10))
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.663015  0.148580  0.980193
# 1   0.713478  0.619036  0.586946
# 2   0.079258  0.195923  0.962479
# 3   0.220901  0.575650  0.929624
# 4   0.307289  0.910089  0.809238
# 5   0.088602  0.858756  0.575100
# 6   0.597550  0.003391  0.158426
# 7   0.524294  0.622006  0.330956
# 8   0.884356  0.532413  0.989198
# 9   0.113992  0.706258  0.009953
# 10  0.098305  0.634802  0.311435
# 11  0.687696  0.262317  0.994510
# 12  0.155237  0.023567  0.201243
# 13  0.986107  0.426543  0.299360
# 14  0.556604  0.459840  0.086019
# 15  0.162505  0.162553  0.766905
# 16  0.350114  0.694393  0.697621
# 17  0.365398  0.809179  0.602207
# 18  0.708962  0.786144  0.717505
# 19  0.111254  0.103850  0.053659

# %%
# we can stack them on top of each other
df2.plot.bar(stacked=True, figsize=(10,5))
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A', y='B', figsize=(12,3))
#plt.show()
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.line(x='A', y='B',figsize=(12,3),lw=.5)
# Out:
# <Axes: xlabel='A'>

# %%
df1.plot.scatter(x='A', y='B', c='0.80', figsize=(12,3))    # c for colour
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# The keyword `c` may be given as the name of a column to provide colors for each point. `cmap` can be used to indicate colormap. <br>
# For all the colormaps, [click here](http://matplotlib.org/users/colormaps.html)

# %%
df1
# Out:
#                    A         B         C         D
# 2022-01-01  0.264339 -0.676687 -2.099222  0.349654
# 2022-01-02  0.979176  0.832978 -0.430471  0.191758
# 2022-01-03  0.675411 -1.260099  0.088787  0.171498
# 2022-01-04  0.991862  0.025384 -0.668000  0.102852
# 2022-01-05  0.543609 -0.012461 -0.337794  0.078712
# ...              ...       ...       ...       ...
# 2023-05-11  0.524144  0.489644  1.619630  0.418202
# 2023-05-12  2.729420  1.816363 -0.429863  0.178136
# 2023-05-13 -1.780389 -0.281302  0.163238  0.687459
# 2023-05-14  0.627451  0.851780  0.001474  0.094138
# 2023-05-15  0.104742 -1.006193  1.212748  0.059543
#
# [500 rows x 4 columns]

# %%
df1.plot.scatter(x='A',y='B', c='D', cmap='coolwarm', figsize=(12,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# We can use 's' to indicate size
df1.plot.scatter(x='A', y='B', s=90,  figsize=(12,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# We can use 's' to indicate size
df1.plot.scatter(x='A', y='B', s=df1['D']*100,  figsize=(12,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.hexbin(x='A',y='B', gridsize=30, cmap='Oranges',  figsize=(12,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# ### Line plots

# %%
gas = pd.read_csv('gas_prices.csv')
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# 13  2003       2.19    1.99    4.35     4.59   4.53   3.47    2.04
# 14  2004       2.72    2.37    4.99     5.24   5.29   3.93    2.03
# 15  2005       3.23    2.89    5.46     5.66   5.74   4.28    2.22
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA
# 0          2.05  2.82  1.16
# 1          2.49  3.01  1.14
# 2          2.65  3.06  1.13
# 3          2.88  2.84  1.11
# 4          2.87  2.99  1.11
# 5          2.94  3.21  1.15
# 6          3.18  3.34  1.23
# 7          3.34  3.83  1.23
# 8          3.04  4.06  1.06
# 9          3.80  4.29  1.17
# 10         4.18  4.58  1.51
# 11         3.76  4.13  1.46
# 12         3.84  4.16  1.36
# 13         4.11  4.70  1.59
# 14         4.51  5.56  1.88
# 15         5.28  5.97  2.30
# 16         5.92  6.36  2.59
# 17         6.21  7.13  2.80
# 18         5.83  7.42  3.27

# %% [markdown]
# ### Using Pandas

# %%
gas['UK'].plot()
# Out:
# <Axes: >

# %%
gas.plot(x='Year', y='USA')
# Out:
# <Axes: xlabel='Year'>

# %%
gas.Year[::3].tolist()
# Out:
# [1990, 1993, 1996, 1999, 2002, 2005, 2008]

# %%
gas.plot(x='Year', y='USA', xticks=gas.Year[::3].tolist())
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ### Using Pyplot

# %%
plt.subplots(figsize=(10,5))
plt.plot(gas['Year'], gas['USA'])
plt.plot(gas['Year'], gas['Canada'])
plt.xticks(gas.Year[::3].tolist())
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18, 'color':'g'})

plt.plot(gas.Year, gas.USA, 'b.-', label='USA')
plt.plot(gas.Year, gas['Canada'], 'r.-', label='Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label='SKorea')
plt.plot(gas.Year, gas.Australia, 'y.-', label='Austrolia')

plt.xticks(gas.Year[::3].tolist()) #[1990, 1993, 1996, 1999, 2002, 2005, 2008]

plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300, bbox_inches ='tight')

plt.show()

# %%
df1
# Out:
#                    A         B         C         D
# 2022-01-01  0.264339 -0.676687 -2.099222  0.349654
# 2022-01-02  0.979176  0.832978 -0.430471  0.191758
# 2022-01-03  0.675411 -1.260099  0.088787  0.171498
# 2022-01-04  0.991862  0.025384 -0.668000  0.102852
# 2022-01-05  0.543609 -0.012461 -0.337794  0.078712
# ...              ...       ...       ...       ...
# 2023-05-11  0.524144  0.489644  1.619630  0.418202
# 2023-05-12  2.729420  1.816363 -0.429863  0.178136
# 2023-05-13 -1.780389 -0.281302  0.163238  0.687459
# 2023-05-14  0.627451  0.851780  0.001474  0.094138
# 2023-05-15  0.104742 -1.006193  1.212748  0.059543
#
# [500 rows x 4 columns]

# %% [markdown]
# ## BoxPlots
# To visualize the distribution of values within each column.

# %%
df2
# Out:
#            X         Y         Z
# 0   0.663015  0.148580  0.980193
# 1   0.713478  0.619036  0.586946
# 2   0.079258  0.195923  0.962479
# 3   0.220901  0.575650  0.929624
# 4   0.307289  0.910089  0.809238
# 5   0.088602  0.858756  0.575100
# 6   0.597550  0.003391  0.158426
# 7   0.524294  0.622006  0.330956
# 8   0.884356  0.532413  0.989198
# 9   0.113992  0.706258  0.009953
# 10  0.098305  0.634802  0.311435
# 11  0.687696  0.262317  0.994510
# 12  0.155237  0.023567  0.201243
# 13  0.986107  0.426543  0.299360
# 14  0.556604  0.459840  0.086019
# 15  0.162505  0.162553  0.766905
# 16  0.350114  0.694393  0.697621
# 17  0.365398  0.809179  0.602207
# 18  0.708962  0.786144  0.717505
# 19  0.111254  0.103850  0.053659

# %%
df2['X'].max()
# Out:
# 0.9861073634759216

# %%
df2['X'].min()
# Out:
# 0.07925816862684165

# %%
df2['X'].quantile(0.25)
# Out:
# np.float64(0.1449259915417432)

# %%
df2['X'].quantile(0.75)
# Out:
# np.float64(0.6691848954334859)

# %%
df2['X'].plot.box()
# Out:
# <Axes: >

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df2.plot.box(vert=False)
# Out:
# <Axes: >

# %% [markdown]
# ## Pie Plot
# We can create a pie plot with  `Series.plot.pie()` or `DataFrame.plot.pie()`. If your data includes any NaN, they will be automatically filled with 0. A ValueError will be raised if there are any negative values in your data.<br>
# Let's try pie plot with df2.<br>
#
# We need to specify a target column by the y argument. When y is specified, pie plot of selected column will be drawn.

# %%
df2
# Out:
#            X         Y         Z
# 0   0.663015  0.148580  0.980193
# 1   0.713478  0.619036  0.586946
# 2   0.079258  0.195923  0.962479
# 3   0.220901  0.575650  0.929624
# 4   0.307289  0.910089  0.809238
# 5   0.088602  0.858756  0.575100
# 6   0.597550  0.003391  0.158426
# 7   0.524294  0.622006  0.330956
# 8   0.884356  0.532413  0.989198
# 9   0.113992  0.706258  0.009953
# 10  0.098305  0.634802  0.311435
# 11  0.687696  0.262317  0.994510
# 12  0.155237  0.023567  0.201243
# 13  0.986107  0.426543  0.299360
# 14  0.556604  0.459840  0.086019
# 15  0.162505  0.162553  0.766905
# 16  0.350114  0.694393  0.697621
# 17  0.365398  0.809179  0.602207
# 18  0.708962  0.786144  0.717505
# 19  0.111254  0.103850  0.053659

# %%
# let's take use X column only
df2.plot.pie(y='X', figsize=(12, 10), autopct='%.2f%%')#,figsize=(12, 4),legend=False)
# Out:
# <Axes: ylabel='X'>

# %% [markdown]
# The plot above does not look nice, lets remove the legend and set the figure size!

# %%
fifa = pd.read_csv('fifa_data.csv')
fifa #select * from fifa
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   31
# 1               1   20801  Cristiano Ronaldo   33
# 2               2  190871          Neymar Jr   26
# 3               3  193080             De Gea   27
# 4               4  192985       K. De Bruyne   27
# ...           ...     ...                ...  ...
# 14583       14583  199908    F. Brown Forbes   26
# 14584       14584  212964        Jo Soo Chul   27
# 14585       14585  231652           S. Banza   21
# 14586       14586  237796         T. Onozawa   20
# 14587       14587  242404          J. Ndecky   21
#
#                                                 Photo     Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png       Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png        Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png          Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png           Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png         Belgium
# ...                                               ...             ...
# 14583  https://cdn.sofifa.org/players/4/19/199908.png      Costa Rica
# 14584  https://cdn.sofifa.org/players/4/19/212964.png  Korea Republic
# 14585  https://cdn.sofifa.org/players/4/19/231652.png          France
# 14586  https://cdn.sofifa.org/players/4/19/237796.png           Japan
# 14587  https://cdn.sofifa.org/players/4/19/242404.png         Senegal
#
#                                        Flag  Overall  Potential  \
# 0       https://cdn.sofifa.org/flags/52.png       94         94
# 1       https://cdn.sofifa.org/flags/38.png       94         94
# 2       https://cdn.sofifa.org/flags/54.png       92         93
# 3       https://cdn.sofifa.org/flags/45.png       91         93
# 4        https://cdn.sofifa.org/flags/7.png       91         92
# ...                                     ...      ...        ...
# 14583   https://cdn.sofifa.org/flags/72.png       61         62
# 14584  https://cdn.sofifa.org/flags/167.png       61         61
# 14585   https://cdn.sofifa.org/flags/18.png       61         70
# 14586  https://cdn.sofifa.org/flags/163.png       61         69
# 14587  https://cdn.sofifa.org/flags/136.png       61         72
#
#                       Club  ... Composure Marking StandingTackle  \
# 0             FC Barcelona  ...      96.0    33.0           28.0
# 1                 Juventus  ...      95.0    28.0           31.0
# 2      Paris Saint-Germain  ...      94.0    27.0           24.0
# 3        Manchester United  ...      68.0    15.0           21.0
# 4          Manchester City  ...      88.0    68.0           58.0
# ...                    ...  ...       ...     ...            ...
# 14583        Korona Kielce  ...      60.0    50.0           58.0
# 14584     Sangju Sangmu FC  ...      60.0    53.0           45.0
# 14585  Racing Club de Lens  ...      58.0    42.0           19.0
# 14586         Cerezo Osaka  ...      47.0    48.0           38.0
# 14587   Fortuna Düsseldorf  ...       NaN     NaN            NaN
#
#        SlidingTackle GKDiving  GKHandling  GKKicking  GKPositioning  \
# 0               26.0      6.0        11.0       15.0           14.0
# 1               23.0      7.0        11.0       15.0           14.0
# 2               33.0      9.0         9.0       15.0           15.0
# 3               13.0     90.0        85.0       87.0           88.0
# 4               51.0     15.0        13.0        5.0           10.0
# ...              ...      ...         ...        ...            ...
# 14583           58.0     12.0        16.0        8.0           14.0
# 14584           48.0     15.0        10.0       13.0           12.0
# 14585           18.0      8.0         7.0        9.0            5.0
# 14586           33.0     13.0        14.0        6.0           11.0
# 14587            NaN      NaN         NaN        NaN            NaN
#
#       GKReflexes Release Clause
# 0            8.0        €226.5M
# 1           11.0        €127.1M
# 2           11.0        €228.1M
# 3           94.0        €138.6M
# 4           13.0        €196.4M
# ...          ...            ...
# 14583        8.0          €428K
# 14584       14.0          €325K
# 14585        6.0          €780K
# 14586       12.0          €544K
# 14587        NaN            NaN
#
# [14588 rows x 89 columns]

# %%
fifa['Weight']
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 14583    181lbs
# 14584    152lbs
# 14585    170lbs
# 14586    137lbs
# 14587       NaN
# Name: Weight, Length: 14588, dtype: object

# %%
def stripdata(x):
    if type(x)==str:
        return float(x[0:3])
    else:
        return x

# %%
# def stripdata(x):
#     if type(x)==str:
#         return int(x.strip('lbs'))
#     else:
#         return x

# %%
stripdata('159lbs')
# Out:
# 159.0

# %%
fifa['Weight'] = fifa['Weight'].apply(stripdata)

# %%
fifa['Weight']
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
#          ...
# 14583    181.0
# 14584    152.0
# 14585    170.0
# 14586    137.0
# 14587      NaN
# Name: Weight, Length: 14588, dtype: float64

# %%
light = fifa[fifa.Weight < 125].count()['Name']
light
# Out:
# np.int64(21)

# %%
light = fifa[fifa.Weight < 125].count()['Name']
light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()['Name']
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()['Name']
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()['Name']
heavy = fifa[fifa.Weight >= 200].count()['Name']

weights = [light,light_medium, medium, medium_heavy, heavy]
weights
# Out:
# [np.int64(21), np.int64(1627), np.int64(8657), np.int64(3897), np.int64(337)]

# %%
plt.figure(figsize=(6,6))

label = ['under 125', '125-150', '150-175', '175-200', 'over 200']

plt.pie(weights, labels=label, autopct='%.2f%%',  pctdistance=0.7)

plt.legend(title="Weight Range")

plt.show()

# %%
plt.figure(figsize=(6,6))

label = ['under 125', '125-150', '150-175', '175-200', 'over 200']

explode = [.4,.2,0,0,.4]

plt.pie(weights, labels=label, explode=explode, autopct='%.2f%%',  pctdistance=0.8)

plt.legend(loc=2, title="Weight Range")

plt.show()

# %% [markdown]
# This was all about the data visualization using pandas. You can see that how convenient it is to use pandas data visualization capabilities while EDA. It balances ease of use with control over the figure. A lot of the plot calls also accept additional arguments of their parent matplotlib library call. <br>
#
# Let's move on to the exercises section now, where we will try to solve some tasks related to pandas data visualization. See you in the next lecture, Good Luck!
#
# # Great Job!
